# %% [markdown]
# <a href="https://colab.research.google.com/github/tnptw/tuberculosis-detection/blob/main/tuberculosis_detection3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Notebook Setup and Import**

# %%
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()

# %%
import numpy as np 
import pandas as pd 
import cv2
import imageio
import io
import shutil
import matplotlib.pyplot as plt
import plotly.offline as py
import plotly.figure_factory as ff
from PIL import Image
import requests
from io import BytesIO
from fastai.vision.all import *
# %matplotlib inline
import os
from fastbook import *
from fastai.vision.widgets import *

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# ## **Create the Training Set**

# %%
path = "/content/gdrive/MyDrive/tuberculosis_chest_x-rays/images_train" #image folder path

def is_tuberculosis(x): return x[12] == '1'
dls = ImageDataLoaders.from_name_func(
    path, get_image_files(path), valid_pct=0.2, seed=42,
    label_func=is_tuberculosis, item_tfms=Resize(224))

print(len(dls.train_ds.items[:])) # Amount of training set
# Out:
# 476

# %%
dls.train.show_batch(max_n=4, nrows=1)

# %%
def label_func(x):
    return "True" if x.name[12] == '1' else "False"

dtb = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=label_func,
    item_tfms=Resize(224))

dls = dtb.dataloaders(path)

# %% [markdown]
# ## **Data Augmentation**

# %%
dtb = dtb.new(item_tfms=Resize(224), batch_tfms=aug_transforms(mult=1))
dls = dtb.dataloaders(path)
dls.train.show_batch(max_n=8, nrows=2, unique=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py:1051: UserWarning:
#
# torch.solve is deprecated in favor of torch.linalg.solveand will be removed in a future PyTorch release.
# torch.linalg.solve has its arguments reversed and does not return the LU factorization.
# To get the LU factorization see torch.lu, which can be used with torch.lu_solve or torch.lu_unpack.
# X = torch.solve(B, A).solution
# should be replaced with
# X = torch.linalg.solve(A, B) (Triggered internally at  ../aten/src/ATen/native/BatchLinearAlgebra.cpp:766.)

# %% [markdown]
# ## **Training the Model**

# %%
learn = cnn_learner(dls, resnet34, metrics=[accuracy, Precision(), Recall(), F1Score()]).to_fp16()

# %%
lrs = learn.lr_find(suggest_funcs=(steep, valley))

# %%
lrs.steep
# Out:
# 1.0964781722577754e-06

# %%
lrs.valley
# Out:
# 0.0012022644514217973

# %%
# learn.fit_one_cycle(3,0.0006918309954926372)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>f1_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.159706</td>
#       <td>0.591729</td>
#       <td>0.731092</td>
#       <td>0.725490</td>
#       <td>0.672727</td>
#       <td>0.698113</td>
#       <td>01:29</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.891563</td>
#       <td>1.196759</td>
#       <td>0.647059</td>
#       <td>1.000000</td>
#       <td>0.236364</td>
#       <td>0.382353</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.751046</td>
#       <td>1.230808</td>
#       <td>0.663866</td>
#       <td>1.000000</td>
#       <td>0.272727</td>
#       <td>0.428571</td>
#       <td>01:24</td>
#     </tr>
#   </tbody>
# </table>

# %%
# learn.unfreeze()

# %%
learn.lr_find()
# Out:
# SuggestedLRs(valley=6.30957365501672e-05)

# %%
learn.fine_tune(epochs=10,
          base_lr=0.0012022644514217973,
          freeze_epochs=1, #how many epochs to train frozen
          lr_mult=100, #train feature extractor with max lr at base_lr/lr_mult
          pct_start=0.2, #start decreasing lr at 
          div=5.0, #start at base_lr (max lr) / div
          cbs=[SaveModelCallback(monitor='f1_score')] # Save Best model
          )
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>f1_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.217144</td>
#       <td>0.595867</td>
#       <td>0.714286</td>
#       <td>0.684211</td>
#       <td>0.709091</td>
#       <td>0.696429</td>
#       <td>01:26</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with f1_score value: 0.6964285714285715.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>f1_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.802286</td>
#       <td>0.665400</td>
#       <td>0.697479</td>
#       <td>0.771429</td>
#       <td>0.490909</td>
#       <td>0.600000</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.744728</td>
#       <td>1.496970</td>
#       <td>0.630252</td>
#       <td>1.000000</td>
#       <td>0.200000</td>
#       <td>0.333333</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.722466</td>
#       <td>1.378553</td>
#       <td>0.647059</td>
#       <td>0.882353</td>
#       <td>0.272727</td>
#       <td>0.416667</td>
#       <td>01:26</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.691557</td>
#       <td>1.287196</td>
#       <td>0.672269</td>
#       <td>0.900000</td>
#       <td>0.327273</td>
#       <td>0.480000</td>
#       <td>01:25</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.666803</td>
#       <td>0.975117</td>
#       <td>0.714286</td>
#       <td>0.818182</td>
#       <td>0.490909</td>
#       <td>0.613636</td>
#       <td>01:25</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.638384</td>
#       <td>0.545658</td>
#       <td>0.806723</td>
#       <td>0.863636</td>
#       <td>0.690909</td>
#       <td>0.767677</td>
#       <td>01:25</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.601534</td>
#       <td>0.401085</td>
#       <td>0.840336</td>
#       <td>0.821429</td>
#       <td>0.836364</td>
#       <td>0.828829</td>
#       <td>01:25</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.557364</td>
#       <td>0.417796</td>
#       <td>0.831933</td>
#       <td>0.843137</td>
#       <td>0.781818</td>
#       <td>0.811321</td>
#       <td>01:25</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.528650</td>
#       <td>0.441946</td>
#       <td>0.848740</td>
#       <td>0.877551</td>
#       <td>0.781818</td>
#       <td>0.826923</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.513178</td>
#       <td>0.451454</td>
#       <td>0.857143</td>
#       <td>0.895833</td>
#       <td>0.781818</td>
#       <td>0.834951</td>
#       <td>01:23</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with f1_score value: 0.6.
# Better model found at epoch 4 with f1_score value: 0.6136363636363636.
# Better model found at epoch 5 with f1_score value: 0.7676767676767676.
# Better model found at epoch 6 with f1_score value: 0.8288288288288289.
# Better model found at epoch 9 with f1_score value: 0.8349514563106797.

# %%
learn.recorder.plot_loss()

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %% [markdown]
# ## **Perform on the Test Set**

# %%
def label_func(x):
    return "True" if x.name[12] == '1' else "False"

dtb = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=label_func,
    item_tfms=Resize(224))

testpath = "/content/gdrive/MyDrive/tuberculosis_chest_x-rays/images_test" #image folder path
dls = dtb.dataloaders(testpath)

learn = cnn_learner(dls, 
                    resnet34, 
                    metrics=[accuracy, Precision(), Recall(), F1Score()]).to_fp16()
#load trained model
learn.load('model');
# Out:
# /usr/local/lib/python3.7/dist-packages/fastai/learner.py:56: UserWarning:
#
# Saved filed doesn't contain an optimizer state.

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %%
interp.print_classification_report()
# Out:
#               precision    recall  f1-score   support
#
#        False       0.80      0.80      0.80         5
#         True       0.88      0.88      0.88         8
#
#     accuracy                           0.85        13
#    macro avg       0.84      0.84      0.84        13
# weighted avg       0.85      0.85      0.85        13
